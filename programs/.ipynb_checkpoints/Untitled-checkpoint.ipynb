# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, json
# python_bitbankccのパッケージをインポート
import python_bitbankcc

# %%
class Trade:
    def __init__(self, buy_sell):
        # 保存してあるキーを読み込み
        f = open('../../key/apikey.txt', 'r', encoding='UTF-8')
        api_key = f.read()
        f.close()
        f = open('../../key/secretkey.txt', 'r', encoding='UTF-8')
        secret_key = f.read()
        f.close()
        
        # APIキー，シークレットの設定
        API_KEY = api_key
        API_SECRET = secret_key
        
        # APIの取得
        self.pub = python_bitbankcc.public()
        self.prv = python_bitbankcc.private(API_KEY, API_SECRET)
        
        # 各データの取得
        self.value = self.pub.get_ticker( 'eth_jpy' )
        self.buy = int(self.value['buy'])
        self.sell = int(self.value['sell'])
        self.buy_sell = buy_sell
        
        # 購入する値段を決定
        self.price_decition()

    def price_decition(self):
        self.buy_price = self.buy+ 3000
    
    def buy_or_sell(self, pair='eth_jpy', amount='0.0001'):
        buy_sell = 'buy' if self.buy_sell==1 else 'sell' if self.buy_sell==2 else 'None'
        value = self.prv.order(
           pair, # ペア
           self.buy_price, # 価格
           amount, # 注文枚数
           buy_sell, # 注文サイド
           'market' # 注文タイプ
        )
        print(json.dumps(value))

# %%
t = Trade(1)

# %%
t.buy
# Out:
# 136967

# %%
t.buy_or_sell()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-b8d8fa86549e> in <module>
# ----> 1 t.buy_or_sell()
#
# <ipython-input-17-32d3365b6ea6> in buy_or_sell(self, pair, amount)
#      31     def buy_or_sell(self, pair='eth_jpy', amount='0.00001'):
#      32         buy_sell = 'buy' if self.buy_sell==1 else 'sell' if self.buy_sell==2 else 'None'
# ---> 33         value = self.prv.order(
#      34            pair, # ペア
#      35            self.buy_price, # 価格
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in order(self, pair, price, amount, side, order_type)
#      93
#      94     def order(self, pair, price, amount, side, order_type):
# ---> 95         return self._post_query('/user/spot/order', {
#      96             'pair': pair,
#      97             'price': price,
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in _post_query(self, path, query)
#      74         uri = self.end_point + path
#      75         response = requests.post(uri, data=data, headers=headers)
# ---> 76         return error_parser(response.json())
#      77
#      78     def get_asset(self):
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/utils.py in error_parser(json_dict)
#      31         contents = ERROR_CODES[code] if code in ERROR_CODES else '不明なエラーです。サポートにお問い合わせ下さい'
#      32         message = 'エラーコード: ' + code + ' 内容: ' + contents
# ---> 33         raise Exception(message)
#      34
#      35 ERROR_CODES = {
#
# Exception: エラーコード: 60004 内容: 指定した数量がしきい値を下回っています

# %%
test = 2
a = 1 if test==1 else 2 if test==2 else 3
a
# Out:
# 2

# %%
class Trade:
    def __init__(self, buy_sell):
        self.pub = python_bitbankcc.public()
        self.value = self.pub.get_ticker( 'eth_jpy' )
        self.buy = int(self.value['buy'])
        self.sell = int(self.value['sell'])
        self.buy_sell = buy_sell
        
        self.price_decition()
        self.buy_or_sell()

    def price_decition(self):
        self.buy_price = self.sell + 3000
    
    def buy_or_sell(self, pair='eth_jpy', amount='0.0001'):
        buy_sell = 'buy' if self.buy_sell==1 else 'sell' if self.buy_sell==2 else 'None'
        value = prv.order(
           pair, # ペア
           self.buy_price, # 価格
           amount, # 注文枚数
           buy_sell, # 注文サイド
           'market' # 注文タイプ
        )
        print(json.dumps(value))

# %%
t = Trade(1)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-96-4b363d3a59e6> in <module>
# ----> 1 t = Trade(1)
#
# <ipython-input-95-5aec31d3d2f2> in __init__(self, buy_sell)
#       8
#       9         self.price_decition()
# ---> 10         self.buy_or_sell()
#      11
#      12     def price_decition(self):
#
# <ipython-input-95-5aec31d3d2f2> in buy_or_sell(self, pair, amount)
#      15     def buy_or_sell(self, pair='eth_jpy', amount='0.0001'):
#      16         buy_sell = 'buy' if self.buy_sell==1 else 'sell' if self.buy_sell==2 else 'None'
# ---> 17         value = prv.order(
#      18            pair, # ペア
#      19            self.buy_price, # 価格
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in order(self, pair, price, amount, side, order_type)
#      93
#      94     def order(self, pair, price, amount, side, order_type):
# ---> 95         return self._post_query('/user/spot/order', {
#      96             'pair': pair,
#      97             'price': price,
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in _post_query(self, path, query)
#      74         uri = self.end_point + path
#      75         response = requests.post(uri, data=data, headers=headers)
# ---> 76         return error_parser(response.json())
#      77
#      78     def get_asset(self):
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/utils.py in error_parser(json_dict)
#      31         contents = ERROR_CODES[code] if code in ERROR_CODES else '不明なエラーです。サポートにお問い合わせ下さい'
#      32         message = 'エラーコード: ' + code + ' 内容: ' + contents
# ---> 33         raise Exception(message)
#      34
#      35 ERROR_CODES = {
#
# Exception: エラーコード: 60002 内容: 成行買い注文の数量上限を上回っています

# %%
buy_or_sell(buy_sell=1,price=10000)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-87-ec24713d5335> in <module>
# ----> 1 buy_or_sell(buy_sell=1,price=10000)
#
# <ipython-input-86-a4ed822d6b86> in buy_or_sell(buy_sell, price, pair, amount)
#       1 def buy_or_sell(buy_sell, price, pair='eth_jpy', amount='0.0001'):
#       2     buy_sell = 'buy' if buy_sell==1 else 'sell' if buy_sell==2 else 'None'
# ----> 3     value = prv.order(
#       4        pair, # ペア
#       5        price, # 価格
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in order(self, pair, price, amount, side, order_type)
#      93
#      94     def order(self, pair, price, amount, side, order_type):
# ---> 95         return self._post_query('/user/spot/order', {
#      96             'pair': pair,
#      97             'price': price,
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in _post_query(self, path, query)
#      74         uri = self.end_point + path
#      75         response = requests.post(uri, data=data, headers=headers)
# ---> 76         return error_parser(response.json())
#      77
#      78     def get_asset(self):
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/utils.py in error_parser(json_dict)
#      31         contents = ERROR_CODES[code] if code in ERROR_CODES else '不明なエラーです。サポートにお問い合わせ下さい'
#      32         message = 'エラーコード: ' + code + ' 内容: ' + contents
# ---> 33         raise Exception(message)
#      34
#      35 ERROR_CODES = {
#
# Exception: エラーコード: 60002 内容: 成行買い注文の数量上限を上回っています

# %%
# 保存してあるキーを読み込み
f = open('../key/apikey.txt', 'r', encoding='UTF-8')
api_key = f.read()
f.close()
f = open('../key/secretkey.txt', 'r', encoding='UTF-8')
secret_key = f.read()
f.close()

# %%
# APIキー，シークレットの設定
API_KEY = api_key
API_SECRET = secret_key
# privte API classのオブジェクトを取得
prv = python_bitbankcc.private(API_KEY, API_SECRET)

# アセット一覧の取得
value = prv.get_asset()

# アセット情報の一例
asset_ex = value['assets'][4]
print('通貨名：' + asset_ex['asset'])
print('保有量：' + asset_ex['onhand_amount'])
print('ロックされている量：' + asset_ex['locked_amount'])
print('利用可能な量：' + asset_ex['free_amount'])
print('引き出し手数料：' + asset_ex['withdrawal_fee'])
# Out:
# 通貨名：eth
# 保有量：0.15580000
# ロックされている量：0.00000000
# 利用可能な量：0.15580000
# 引き出し手数料：0.00500000

# %%
# APIキー，シークレットの設定
API_KEY = api_key
API_SECRET = secret_key
# privte API classのオブジェクトを取得
prv = python_bitbankcc.private(API_KEY, API_SECRET)

# アセット一覧の取得
value = prv.get_asset()

# アセット情報の一例
asset_ex = value['assets'][4]
print('通貨名：' + asset_ex['asset'])
print('保有量：' + asset_ex['onhand_amount'])
print('ロックされている量：' + asset_ex['locked_amount'])
print('利用可能な量：' + asset_ex['free_amount'])
print('引き出し手数料：' + asset_ex['withdrawal_fee'])
# Out:
# 通貨名：eth
# 保有量：0.15580000
# ロックされている量：0.00000000
# 利用可能な量：0.15580000
# 引き出し手数料：0.00500000

# %%
# public API classのオブジェクトを取得
pub = python_bitbankcc.public()

# ティッカー情報を取得
value = pub.get_ticker( 'eth_jpy' )

# 最近の約定価格
print('last:' + value['last'])
# 現在の売り注文の最安値
print('sell:' + value['sell'])
# 現在の買い注文の最安値
print('buy:' + value['buy'])
# Out:
# last:136653
# sell:136775
# buy:136654

# %%
# private API classのオブジェクトを取得
prv = python_bitbankcc.private(API_KEY, API_SECRET)
# ユーザーのアクティブな注文を全て取得
value = prv.get_active_orders(
   'eth_jpy' # ペア
)
value
# Out:
# {'orders': []}

# %%
# ユーザーのアセット(資産)情報を取得
value = prv.get_asset()
value["assets"][4]
# Out:
# {'asset': 'eth',
#  'amount_precision': 8,
#  'onhand_amount': '0.15580000',
#  'locked_amount': '0.00000000',
#  'free_amount': '0.15580000',
#  'stop_deposit': False,
#  'stop_withdrawal': False,
#  'withdrawal_fee': '0.00500000'}

# %%
# 注文する
value = prv.order(
   'eth_jpy', # ペア
   '120000', # 価格
   '0.0001', # 注文枚数
   'buy', # 注文サイド
   'market' # 注文タイプ
)
print(json.dumps(value))
# Out:
# {"order_id": 12247121638, "pair": "eth_jpy", "side": "buy", "type": "market", "start_amount": "0.0001", "remaining_amount": "0.0001", "executed_amount": "0.0000", "average_price": "0", "ordered_at": 1611385919554, "status": "UNFILLED"}

# %%
# 注文をキャンセルする
value = prv.cancel_order(
   'eth_jpy', # ペア
   '12247121638' # 注文ID
)
print(json.dumps(value))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-52-44b8f0a3ead0> in <module>
#       1 # 注文をキャンセルする
# ----> 2 value = prv.cancel_order(
#       3    'eth_jpy', # ペア
#       4    '12247121638' # 注文ID
#       5 )
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in cancel_order(self, pair, order_id)
#     102
#     103     def cancel_order(self, pair, order_id):
# --> 104         return self._post_query('/user/spot/cancel_order', {
#     105             'pair': pair,
#     106             'order_id': order_id
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/private_api.py in _post_query(self, path, query)
#      74         uri = self.end_point + path
#      75         response = requests.post(uri, data=data, headers=headers)
# ---> 76         return error_parser(response.json())
#      77
#      78     def get_asset(self):
#
# /anaconda3/envs/bitcoin/lib/python3.9/site-packages/python_bitbankcc/utils.py in error_parser(json_dict)
#      31         contents = ERROR_CODES[code] if code in ERROR_CODES else '不明なエラーです。サポートにお問い合わせ下さい'
#      32         message = 'エラーコード: ' + code + ' 内容: ' + contents
# ---> 33         raise Exception(message)
#      34
#      35 ERROR_CODES = {
#
# Exception: エラーコード: 50027 内容: 不明なエラーです。サポートにお問い合わせ下さい

# %%
# public API classのオブジェクトを取得
pub = python_bitbankcc.public()

# ティッカー情報を取得
value = pub.get_ticker( 'eth_jpy' )

# 最近の約定価格
print('last:' + value['last'])
# 現在の売り注文の最安値
print('sell:' + value['sell'])
# 現在の買い注文の最安値
print('buy:' + value['buy'])
# Out:
# last:130378
# sell:130426
# buy:130378

# %%
import json
# public API classのオブジェクトを取得
pub = python_bitbankcc.public()

# 現在の価格情報を取得
value = pub.get_ticker(
   'btc_jpy' # ペア
)
print(json.dumps(value))
# Out:
# {"sell": "3436000", "buy": "3433873", "high": "3512980", "low": "3158652", "last": "3436000", "vol": "1826.5774", "timestamp": 1611384494274}

# %%
# 直近の板情報を取得
value = pub.get_depth(
   'btc_jpy' # ペア
)
pd.DataFrame(value)
# Out:
#                   asks               bids      timestamp  sequenceId
# 0    [3416511, 0.1796]  [3415969, 0.0001]  1611380672693  1568836733
# 1    [3416512, 1.9165]  [3415693, 0.0400]  1611380672693  1568836733
# 2    [3418124, 0.0300]  [3414875, 0.2198]  1611380672693  1568836733
# 3    [3418213, 0.7000]  [3414874, 0.1600]  1611380672693  1568836733
# 4    [3418214, 0.2900]  [3414085, 0.0001]  1611380672693  1568836733
# ..                 ...                ...            ...         ...
# 195  [3571500, 0.0800]  [3188000, 0.0319]  1611380672693  1568836733
# 196  [3571966, 0.0004]  [3187172, 0.0001]  1611380672693  1568836733
# 197  [3574432, 0.0006]  [3185650, 0.0156]  1611380672693  1568836733
# 198  [3575000, 0.1000]  [3185242, 0.0215]  1611380672693  1568836733
# 199  [3576000, 0.9173]  [3185000, 0.0675]  1611380672693  1568836733
#
# [200 rows x 4 columns]

# %%
# 指定した日にちの約定情報を取得
value = pub.get_transactions(
   'btc_jpy', # ペア
   '20200313' # YYYYMMDD 型の日付
)
pd.DataFrame(value['transactions'])
# Out:
#         transaction_id  side   price  amount    executed_at
# 0           1006893233   buy  523998  0.0100  1584057600525
# 1           1006893237   buy  523997  0.0100  1584057601448
# 2           1006893238  sell  523005  0.0100  1584057601701
# 3           1006893239  sell  523005  0.0319  1584057602633
# 4           1006893242  sell  523005  0.1000  1584057603239
# ...                ...   ...     ...     ...            ...
# 105311      1007173096  sell  623999  0.0001  1584143985866
# 105312      1007173097  sell  623999  0.0001  1584143986025
# 105313      1007173098   buy  624010  0.0040  1584143986860
# 105314      1007173099  sell  624009  0.0001  1584143987395
# 105315      1007173100  sell  623999  0.0049  1584143987395
#
# [105316 rows x 5 columns]

# %%
# 蝋燭足チャートを取得
value = pub.get_candlestick(
   'btc_jpy', # ペア
   '1min', # タイプ
   '20200313' # YYYYMMDD 型の日付
)
ohlcv = value['candlestick'][0]['ohlcv']
[ohlcv for n in range(len(ohlcv))]
ohlcv
# Out:
# [['523998', '530000', '522295', '530000', '13.6205', 1584057600000],
#  ['530000', '545000', '529800', '536949', '14.2482', 1584057660000],
#  ['536949', '542000', '530596', '540761', '12.7306', 1584057720000],
#  ['538997', '544999', '532012', '532974', '13.4700', 1584057780000],
#  ['532982', '535171', '532010', '533785', '9.8945', 1584057840000],
#  ['533785', '533852', '528692', '529813', '20.4086', 1584057900000],
#  ['529813', '538995', '520011', '520949', '14.2782', 1584057960000],
#  ['520797', '525469', '520011', '524692', '5.3506', 1584058020000],
#  ['524693', '526034', '520010', '522287', '8.4549', 1584058080000],
#  ['520543', '523070', '515633', '518687', '11.8557', 1584058140000],
#  ['519285', '520000', '510000', '514315', '10.5255', 1584058200000],
#  ['510000', '514313', '508791', '512249', '15.6013', 1584058260000],
#  ['514307', '514327', '512000', '512252', '17.3906', 1584058320000],
#  ['512252', '513911', '512201', '512309', '5.3024', 1584058380000],
#  ['512201', '521574', '512201', '517338', '23.0583', 1584058440000],
#  ['515167', '520000', '514131', '519999', '5.8652', 1584058500000],
#  ['520000', '523997', '520000', '523995', '3.7258', 1584058560000],
#  ['523995', '530000', '520683', '523131', '8.4247', 1584058620000],
#  ['523130', '523130', '520685', '520705', '3.6978', 1584058680000],
#  ['520714', '521938', '520000', '520575', '7.7949', 1584058740000],
#  ['520574', '521097', '516000', '519296', '6.2716', 1584058800000],
#  ['519292', '520001', '516800', '517347', '22.3712', 1584058860000],
#  ['518428', '519117', '516318', '516318', '5.3169', 1584058920000],
#  ['516318', '517995', '511503', '514046', '14.5493', 1584058980000],
#  ['514998', '515635', '512000', '514992', '3.6690', 1584059040000],
#  ['514990', '516500', '511662', '516500', '15.4754', 1584059100000],
#  ['516499', '518289', '513024', '517000', '4.1893', 1584059160000],
#  ['517000', '517000', '513061', '515984', '2.8181', 1584059220000],
#  ['515985', '518000', '515517', '518000', '5.1112', 1584059280000],
#  ['518000', '521082', '517041', '519999', '2.3124', 1584059340000],
#  ['519999', '521081', '518477', '521081', '1.5713', 1584059400000],
#  ['521081', '525000', '521001', '521415', '5.4277', 1584059460000],
#  ['521415', '528000', '518512', '521010', '14.4146', 1584059520000],
#  ['521018', '527999', '521018', '523280', '2.6912', 1584059580000],
#  ['523281', '528000', '522164', '527195', '3.8584', 1584059640000],
#  ['525000', '527900', '522200', '523512', '8.9635', 1584059700000],
#  ['523511', '523511', '518511', '518512', '10.9139', 1584059760000],
#  ['518512', '520314', '518512', '519489', '6.2586', 1584059820000],
#  ['519489', '524000', '518826', '522144', '1.1823', 1584059880000],
#  ['522482', '524006', '520317', '520320', '1.9451', 1584059940000],
#  ['520321', '523000', '520000', '520000', '5.3624', 1584060000000],
#  ['520000', '520960', '514000', '518579', '11.1912', 1584060060000],
#  ['514001', '518586', '514001', '516411', '8.3753', 1584060120000],
#  ['514011', '516412', '514000', '514000', '3.8371', 1584060180000],
#  ['514162', '516383', '514000', '514000', '5.7395', 1584060240000],
#  ['514100', '515889', '510001', '510001', '4.7958', 1584060300000],
#  ['510001', '511898', '510001', '510010', '7.6696', 1584060360000],
#  ['510010', '510010', '510000', '510000', '11.4692', 1584060420000],
#  ['510000', '510001', '510000', '510000', '16.8427', 1584060480000],
#  ['510000', '511000', '508652', '508700', '7.4050', 1584060540000],
#  ['508700', '513403', '508700', '511900', '6.6564', 1584060600000],
#  ['511900', '520000', '511899', '513001', '7.2145', 1584060660000],
#  ['513001', '517771', '510499', '511756', '5.3822', 1584060720000],
#  ['511756', '518000', '511756', '516000', '2.0709', 1584060780000],
#  ['516000', '523000', '516000', '520010', '8.4017', 1584060840000],
#  ['520010', '526000', '518001', '526000', '3.3344', 1584060900000],
#  ['525000', '527996', '519550', '525000', '8.9723', 1584060960000],
#  ['525000', '526000', '519935', '523991', '5.4239', 1584061020000],
#  ['523991', '528057', '522000', '527683', '8.7197', 1584061080000],
#  ['525096', '527685', '525000', '525003', '4.5188', 1584061140000],
#  ['525003', '528200', '525003', '528200', '2.0433', 1584061200000],
#  ['528200', '534999', '528200', '534999', '6.5277', 1584061260000],
#  ['534999', '538888', '528010', '528716', '12.4580', 1584061320000],
#  ['528398', '530393', '527753', '530393', '5.0979', 1584061380000],
#  ['530000', '546000', '530000', '544001', '14.2922', 1584061440000],
#  ['544002', '549294', '539047', '543999', '13.1989', 1584061500000],
#  ['544000', '549000', '540010', '541266', '5.2859', 1584061560000],
#  ['541267', '545000', '528013', '536000', '5.3036', 1584061620000],
#  ['536000', '545000', '533374', '535894', '2.3654', 1584061680000],
#  ['535894', '536780', '534003', '534003', '0.5938', 1584061740000],
#  ['534003', '537128', '534000', '534002', '1.0140', 1584061800000],
#  ['534002', '545005', '534002', '544000', '3.3079', 1584061860000],
#  ['544001', '545000', '540000', '540003', '1.9570', 1584061920000],
#  ['540003', '541000', '536000', '536001', '1.3684', 1584061980000],
#  ['539664', '547429', '536000', '537000', '3.9194', 1584062040000],
#  ['539998', '540000', '537001', '537005', '4.7808', 1584062100000],
#  ['537005', '543000', '536001', '536001', '6.2875', 1584062160000],
#  ['536002', '540000', '535002', '535004', '1.7106', 1584062220000],
#  ['535006', '539988', '535000', '539988', '1.5247', 1584062280000],
#  ['537258', '540000', '534002', '534270', '4.9381', 1584062340000],
#  ['534270', '539552', '534002', '534050', '6.3125', 1584062400000],
#  ['534050', '540000', '534003', '534003', '2.9110', 1584062460000],
#  ['534003', '539357', '533800', '533804', '5.0883', 1584062520000],
#  ['533800', '538473', '532000', '532007', '4.4838', 1584062580000],
#  ['532007', '532496', '530001', '532000', '8.4553', 1584062640000],
#  ['532000', '533016', '530000', '533016', '13.2533', 1584062700000],
#  ['532159', '535000', '530422', '530876', '3.7818', 1584062760000],
#  ['534000', '535000', '532000', '532000', '0.7123', 1584062820000],
#  ['532002', '534007', '528800', '532196', '9.5929', 1584062880000],
#  ['533595', '537500', '528000', '537500', '10.5429', 1584062940000],
#  ['538153', '540000', '526000', '536009', '10.1658', 1584063000000],
#  ['534004', '539000', '528000', '530006', '8.3866', 1584063060000],
#  ['530010', '536741', '530000', '530003', '5.0070', 1584063120000],
#  ['531000', '533820', '531000', '533820', '0.1520', 1584063180000],
#  ['533820', '536412', '533820', '535324', '1.7631', 1584063240000],
#  ['535002', '535795', '534038', '535004', '2.9819', 1584063300000],
#  ['535007', '535007', '535004', '535004', '0.7061', 1584063360000],
#  ['535004', '535005', '531758', '532994', '0.7405', 1584063420000],
#  ['531763', '532000', '530010', '530013', '0.7251', 1584063480000],
#  ['530014', '530985', '530010', '530985', '5.4677', 1584063540000],
#  ['530010', '531000', '528500', '528500', '3.9619', 1584063600000],
#  ['528500', '530597', '525000', '525000', '4.6489', 1584063660000],
#  ['525000', '527439', '520000', '520001', '7.4312', 1584063720000],
#  ['522992', '523026', '520000', '520001', '5.5829', 1584063780000],
#  ['520001', '520002', '520000', '520000', '1.5585', 1584063840000],
#  ['520000', '520000', '515000', '515000', '5.3727', 1584063900000],
#  ['515001', '518195', '510500', '513000', '4.4461', 1584063960000],
#  ['513000', '516942', '512000', '512704', '5.1475', 1584064020000],
#  ['512995', '520793', '512000', '515942', '5.7622', 1584064080000],
#  ['515942', '519018', '512000', '512001', '2.3297', 1584064140000],
#  ['514987', '514988', '512000', '513990', '1.7583', 1584064200000],
#  ['512000', '512000', '503010', '507217', '24.0803', 1584064260000],
#  ['505710', '505710', '501000', '501000', '10.6949', 1584064320000],
#  ['501581', '503446', '500001', '503446', '15.8446', 1584064380000],
#  ['500988', '503000', '500000', '500006', '11.9571', 1584064440000],
#  ['500006', '502999', '500000', '500001', '6.7311', 1584064500000],
#  ['500001', '502000', '500000', '500005', '5.9327', 1584064560000],
#  ['500007', '500423', '500000', '500298', '12.6502', 1584064620000],
#  ['500000', '500001', '499999', '499999', '45.4369', 1584064680000],
#  ['499999', '500000', '493000', '494175', '8.0770', 1584064740000],
#  ['493200', '498999', '491000', '491000', '7.8654', 1584064800000],
#  ['491000', '494780', '486993', '486993', '11.7841', 1584064860000],
#  ['486997', '490000', '482000', '482000', '12.9046', 1584064920000],
#  ['484995', '496797', '482000', '494129', '17.6534', 1584064980000],
#  ['494131', '510000', '492000', '503946', '13.6108', 1584065040000],
#  ['503946', '503946', '490000', '490003', '6.6757', 1584065100000],
#  ['490002', '504000', '490000', '492094', '11.2265', 1584065160000],
#  ['495756', '495756', '486000', '486000', '5.6612', 1584065220000],
#  ['486000', '488000', '485001', '485726', '6.5810', 1584065280000],
#  ['485001', '485722', '480003', '482325', '6.7809', 1584065340000],
#  ['480010', '485002', '480010', '482465', '8.4659', 1584065400000],
#  ['485000', '485000', '480576', '484998', '7.0563', 1584065460000],
#  ['484999', '484999', '480003', '483996', '5.8241', 1584065520000],
#  ['480016', '483997', '475000', '475000', '28.9560', 1584065580000],
#  ['475000', '475001', '465555', '465555', '19.3794', 1584065640000],
#  ['465556', '467999', '465000', '465123', '4.2331', 1584065700000],
#  ['465124', '467500', '465000', '465173', '9.0827', 1584065760000],
#  ['466998', '469278', '465000', '468343', '16.7318', 1584065820000],
#  ['466000', '474342', '465000', '474341', '13.0345', 1584065880000],
#  ['474342', '486001', '465000', '486001', '15.7115', 1584065940000],
#  ['482887', '490100', '476543', '484000', '6.3461', 1584066000000],
#  ['486286', '490100', '465000', '476035', '10.1823', 1584066060000],
#  ['480000', '480591', '468001', '480000', '11.0990', 1584066120000],
#  ['479227', '480000', '465000', '474235', '3.9533', 1584066180000],
#  ['473993', '473993', '466000', '468598', '6.3832', 1584066240000],
#  ['468598', '472000', '466102', '466152', '1.2829', 1584066300000],
#  ['470601', '474000', '470000', '471629', '6.8384', 1584066360000],
#  ['471628', '489536', '468000', '484237', '17.7544', 1584066420000],
#  ['488971', '496000', '484435', '494394', '12.9506', 1584066480000],
#  ['493513', '500000', '492000', '499999', '7.3401', 1584066540000],
#  ['499999', '526869', '499999', '524750', '11.0973', 1584066600000],
#  ['524750', '549200', '523051', '549200', '31.4261', 1584066660000],
#  ['547641', '560788', '547641', '559186', '30.2805', 1584066720000],
#  ['559186', '560000', '536010', '538311', '21.5624', 1584066780000],
#  ['539424', '540000', '521003', '534999', '22.5781', 1584066840000],
#  ['534999', '544000', '528000', '534009', '24.8589', 1584066900000],
#  ['534013', '539998', '532012', '539977', '9.8280', 1584066960000],
#  ['538998', '556534', '536735', '556534', '27.6363', 1584067020000],
#  ['558000', '589000', '552676', '589000', '25.3426', 1584067080000],
#  ['589000', '614999', '582000', '608000', '28.1422', 1584067140000],
#  ['608010', '619998', '600000', '600259', '27.3699', 1584067200000],
#  ['600259', '607139', '592000', '600258', '18.6751', 1584067260000],
#  ['593239', '600252', '552004', '592008', '21.0447', 1584067320000],
#  ['592010', '595999', '573000', '595999', '16.7602', 1584067380000],
#  ['592854', '599879', '584380', '592034', '8.0190', 1584067440000],
#  ['592035', '599999', '590000', '590000', '9.6374', 1584067500000],
#  ['590000', '593441', '585000', '585001', '6.3319', 1584067560000],
#  ['585001', '600000', '540000', '560000', '22.4583', 1584067620000],
#  ['560000', '571725', '540000', '560000', '17.4358', 1584067680000],
#  ['560000', '570000', '544000', '556000', '12.8051', 1584067740000],
#  ['556000', '563725', '548001', '554996', '7.6139', 1584067800000],
#  ['554996', '555000', '534716', '540942', '14.0015', 1584067860000],
#  ['540941', '544010', '533000', '536010', '9.9970', 1584067920000],
#  ['540003', '556010', '540000', '543961', '5.5505', 1584067980000],
#  ['543787', '549000', '536050', '543838', '5.1717', 1584068040000],
#  ['545407', '548010', '526263', '526263', '16.6998', 1584068100000],
#  ['527382', '539996', '520796', '528702', '8.9407', 1584068160000],
#  ['527995', '540005', '522371', '532105', '16.0141', 1584068220000],
#  ['536010', '548000', '529292', '534559', '7.0994', 1584068280000],
#  ['535995', '548000', '532862', '539349', '7.3781', 1584068340000],
#  ['539349', '548713', '535008', '544014', '6.8742', 1584068400000],
#  ['548713', '560000', '544014', '555003', '7.6334', 1584068460000],
#  ['559945', '570000', '552000', '556001', '19.2146', 1584068520000],
#  ['560000', '570000', '556003', '565000', '14.9225', 1584068580000],
#  ['565000', '568000', '560010', '564850', '11.8072', 1584068640000],
#  ['564845', '567993', '553520', '560000', '13.7283', 1584068700000],
#  ['560001', '562997', '560001', '562601', '4.9282', 1584068760000],
#  ['562990', '568001', '560000', '568001', '7.1416', 1584068820000],
#  ['567999', '576000', '564000', '570089', '4.8680', 1584068880000],
#  ['570089', '575905', '568018', '569998', '10.4309', 1584068940000],
#  ['574994', '574994', '564320', '565372', '5.9788', 1584069000000],
#  ['569984', '572100', '564000', '572100', '5.1803', 1584069060000],
#  ['568279', '580000', '568278', '577892', '10.1943', 1584069120000],
#  ['577733', '587000', '575383', '586995', '4.2287', 1584069180000],
#  ['587000', '590000', '587000', '587721', '7.2635', 1584069240000],
#  ['587723', '595555', '587721', '595554', '9.3278', 1584069300000],
#  ['595554', '600010', '595338', '600010', '15.3756', 1584069360000],
#  ['597002', '604000', '597002', '603282', '6.1949', 1584069420000],
#  ['602802', '609998', '602801', '609998', '5.7106', 1584069480000],
#  ['608792', '659500', '608790', '650001', '33.1442', 1584069540000],
#  ['659500', '674321', '640010', '640012', '18.5860', 1584069600000],
#  ['640012', '647999', '601000', '624675', '18.1977', 1584069660000],
#  ['624675', '626205', '615000', '617659', '10.9676', 1584069720000],
#  ['621999', '630000', '615000', '625001', '10.4456', 1584069780000],
#  ['628000', '630000', '622000', '624000', '6.3481', 1584069840000],
#  ['625001', '630000', '622000', '630000', '13.6708', 1584069900000],
#  ['626995', '640000', '625001', '639998', '17.0383', 1584069960000],
#  ['632111', '650000', '627988', '644000', '30.2535', 1584070020000],
#  ['644000', '650000', '644000', '645580', '16.1057', 1584070080000],
#  ['649500', '666698', '645000', '660000', '23.5394', 1584070140000],
#  ['660000', '666700', '660000', '666700', '7.3930', 1584070200000],
#  ['666500', '673000', '666500', '670002', '14.7244', 1584070260000],
#  ['670002', '680000', '670000', '677006', '23.1448', 1584070320000],
#  ['677006', '680000', '677000', '679999', '10.2928', 1584070380000],
#  ['679999', '680001', '679859', '680001', '13.3624', 1584070440000],
#  ['680001', '683931', '613000', '649999', '46.5228', 1584070500000],
#  ['650000', '670000', '613002', '652000', '34.1134', 1584070560000],
#  ['652001', '660000', '621000', '650996', '9.0716', 1584070620000],
#  ['651000', '656000', '650001', '656000', '9.5653', 1584070680000],
#  ['654998', '658500', '630000', '640000', '18.2399', 1584070740000],
#  ['640000', '650000', '623000', '623002', '14.6225', 1584070800000],
#  ['629997', '630001', '620000', '621000', '15.3065', 1584070860000],
#  ['621000', '621000', '612010', '614682', '13.5849', 1584070920000],
#  ['614682', '614683', '601500', '601500', '10.6715', 1584070980000],
#  ['609999', '610000', '600001', '603991', '13.1197', 1584071040000],
#  ['603991', '604010', '600000', '600000', '14.6586', 1584071100000],
#  ['600003', '602923', '590011', '592010', '25.0835', 1584071160000],
#  ['592009', '596007', '592007', '592099', '4.5398', 1584071220000],
#  ['592009', '593000', '588501', '589000', '10.5635', 1584071280000],
#  ['589000', '589001', '586000', '587998', '3.8671', 1584071340000],
#  ['587998', '590255', '580011', '590001', '15.1479', 1584071400000],
#  ['590000', '590255', '582888', '587000', '18.6853', 1584071460000],
#  ['587000', '587119', '580002', '583002', '6.1337', 1584071520000],
#  ['586162', '598000', '583002', '592100', '5.1042', 1584071580000],
#  ['592100', '620000', '592100', '599364', '29.1601', 1584071640000],
#  ['599364', '610000', '599363', '602051', '2.8774', 1584071700000],
#  ['602051', '611000', '602051', '611000', '4.6148', 1584071760000],
#  ['611000', '620000', '611000', '613760', '6.8371', 1584071820000],
#  ['615000', '619570', '615000', '616000', '3.8406', 1584071880000],
#  ['616000', '624246', '615003', '624246', '11.4304', 1584071940000],
#  ['624246', '631422', '617586', '622000', '8.0243', 1584072000000],
#  ['622001', '622850', '600000', '600001', '11.6531', 1584072060000],
#  ['605622', '615000', '600055', '608624', '6.8618', 1584072120000],
#  ['608622', '613999', '608622', '609999', '7.3691', 1584072180000],
#  ['610000', '615998', '608623', '613178', '7.1505', 1584072240000],
#  ['610002', '616010', '610002', '612224', '4.2278', 1584072300000],
#  ['612226', '616555', '611000', '614996', '11.9265', 1584072360000],
#  ['614996', '614997', '611500', '612238', '2.6082', 1584072420000],
#  ['611501', '612238', '600001', '607998', '11.0738', 1584072480000],
#  ['607997', '608000', '603001', '605000', '3.3359', 1584072540000],
#  ['604999', '620000', '604999', '610208', '4.8474', 1584072600000],
#  ['610207', '610207', '605001', '606379', '2.2103', 1584072660000],
#  ['605500', '609999', '605000', '606295', '2.8916', 1584072720000],
#  ['609998', '609999', '602000', '602000', '11.8187', 1584072780000],
#  ['602000', '609999', '599999', '599999', '6.7536', 1584072840000],
#  ['599999', '605000', '599999', '605000', '2.3306', 1584072900000],
#  ['600010', '601009', '599999', '601009', '8.9260', 1584072960000],
#  ['601298', '603315', '590340', '590340', '13.7375', 1584073020000],
#  ['592010', '592010', '583002', '583002', '11.3957', 1584073080000],
#  ['583000', '589997', '576000', '588996', '13.4529', 1584073140000],
#  ['584013', '588999', '576789', '580500', '9.7237', 1584073200000],
#  ['580500', '596000', '580012', '585002', '2.0306', 1584073260000],
#  ['585002', '588008', '580013', '580825', '14.1509', 1584073320000],
#  ['580825', '584911', '570431', '576012', '9.9660', 1584073380000],
#  ['580007', '582900', '573000', '581111', '6.7859', 1584073440000],
#  ['581111', '581120', '570001', '575896', '9.0100', 1584073500000],
#  ['575895', '577807', '562000', '562001', '19.1276', 1584073560000],
#  ['562001', '562001', '561000', '561821', '3.1179', 1584073620000],
#  ['561820', '563403', '560254', '560255', '4.2914', 1584073680000],
#  ['560255', '560255', '558431', '559092', '4.5035', 1584073740000],
#  ['558431', '569016', '555557', '565173', '9.2322', 1584073800000],
#  ['560012', '578100', '560012', '567001', '7.9637', 1584073860000],
#  ['567001', '570553', '563232', '567315', '7.6279', 1584073920000],
#  ['567415', '569997', '567315', '567315', '1.9371', 1584073980000],
#  ['567316', '569997', '567300', '567403', '4.4055', 1584074040000],
#  ['567300', '570553', '567000', '567300', '3.7320', 1584074100000],
#  ['567002', '567867', '563137', '563138', '4.4048', 1584074160000],
#  ['564999', '567001', '560000', '560002', '3.3413', 1584074220000],
#  ['560002', '560003', '551500', '555998', '12.4289', 1584074280000],
#  ['552003', '560005', '552003', '557583', '4.3941', 1584074340000],
#  ['556111', '560000', '555101', '555255', '4.8239', 1584074400000],
#  ['557586', '557999', '550001', '554695', '11.4924', 1584074460000],
#  ['552011', '554696', '551000', '551001', '2.6953', 1584074520000],
#  ['551990', '551990', '543002', '543002', '23.0804', 1584074580000],
#  ['547995', '550001', '543002', '545000', '7.1964', 1584074640000],
#  ['545000', '551989', '544010', '547020', '7.6624', 1584074700000],
#  ['547020', '548488', '545925', '548482', '4.7280', 1584074760000],
#  ['548481', '548488', '542091', '548003', '5.7945', 1584074820000],
#  ['545000', '547443', '542000', '544980', '5.9493', 1584074880000],
#  ['544976', '548994', '543886', '543890', '5.3489', 1584074940000],
#  ['543891', '548009', '542001', '543888', '17.6201', 1584075000000],
#  ['543505', '548008', '540000', '544008', '6.3694', 1584075060000],
#  ['543999', '544008', '539987', '542479', '10.6507', 1584075120000],
#  ['542479', '546000', '542479', '546000', '6.3801', 1584075180000],
#  ['546000', '549275', '545000', '545000', '8.8865', 1584075240000],
#  ['547000', '548626', '543000', '543000', '6.2652', 1584075300000],
#  ['546386', '549275', '539987', '539988', '8.0844', 1584075360000],
#  ['540000', '547000', '536000', '536002', '4.2404', 1584075420000],
#  ['537998', '539994', '530001', '536001', '9.2745', 1584075480000],
#  ['533778', '538000', '533778', '538000', '6.2610', 1584075540000],
#  ['536179', '545000', '535983', '545000', '11.5649', 1584075600000],
#  ['545000', '550000', '543831', '549998', '12.8719', 1584075660000],
#  ['549998', '559758', '549998', '559758', '19.5866', 1584075720000],
#  ['553007', '561000', '553007', '559314', '6.5459', 1584075780000],
#  ['559314', '569000', '559314', '565052', '14.8005', 1584075840000],
#  ['563232', '567671', '563232', '563716', '3.5668', 1584075900000],
#  ['563240', '580000', '563238', '572012', '39.4671', 1584075960000],
#  ['570171', '579900', '564033', '572025', '9.0440', 1584076020000],
#  ['575400', '578000', '568557', '569993', '12.5195', 1584076080000],
#  ['569990', '576000', '566327', '575998', '3.4345', 1584076140000],
#  ['575998', '576009', '571910', '575999', '6.4025', 1584076200000],
#  ['575999', '579000', '575201', '578998', '9.8933', 1584076260000],
#  ['577001', '580000', '577000', '577001', '8.6863', 1584076320000],
#  ['577001', '578297', '577000', '577002', '4.1001', 1584076380000],
#  ['577006', '578000', '577000', '577000', '2.6603', 1584076440000],
#  ['577001', '577001', '565000', '566114', '16.5006', 1584076500000],
#  ['567825', '583000', '567825', '570101', '8.6650', 1584076560000],
#  ['570101', '580000', '570101', '576010', '6.8325', 1584076620000],
#  ['572012', '581000', '572011', '575847', '4.7680', 1584076680000],
#  ['577105', '581000', '573000', '576938', '11.1454', 1584076740000],
#  ['576938', '580010', '576000', '578002', '5.0805', 1584076800000],
#  ['578002', '581000', '578001', '579990', '3.8926', 1584076860000],
#  ['579990', '583000', '579414', '581003', '7.4394', 1584076920000],
#  ['581003', '581005', '573000', '576017', '7.9146', 1584076980000],
#  ['576017', '577000', '573000', '573001', '7.6617', 1584077040000],
#  ['573001', '576046', '572000', '573860', '6.8643', 1584077100000],
#  ['573860', '573860', '566186', '572687', '8.0260', 1584077160000],
#  ['572687', '575000', '571602', '572001', '1.7969', 1584077220000],
#  ['572000', '572004', '569232', '571351', '1.7887', 1584077280000],
#  ['571350', '572000', '571350', '571351', '1.7687', 1584077340000],
#  ['571351', '571499', '550000', '563003', '16.0881', 1584077400000],
#  ['563004', '567149', '561439', '566999', '3.3878', 1584077460000],
#  ['566998', '566998', '561483', '562538', '0.9139', 1584077520000],
#  ['562538', '564311', '558377', '562999', '9.1675', 1584077580000],
#  ['561952', '562998', '560547', '560549', '2.7043', 1584077640000],
#  ['560548', '564000', '559654', '563998', '9.5665', 1584077700000],
#  ['563998', '564311', '560412', '564306', '1.1941', 1584077760000],
#  ['563574', '564097', '562006', '562094', '1.2971', 1584077820000],
#  ['563599', '564304', '562216', '564302', '1.8720', 1584077880000],
#  ['564302', '564303', '563519', '563519', '1.4265', 1584077940000],
#  ['563999', '565000', '562720', '564999', '3.9148', 1584078000000],
#  ['564259', '565000', '563535', '564454', '4.2384', 1584078060000],
#  ['564454', '564881', '563600', '563950', '2.9044', 1584078120000],
#  ['563950', '573000', '563536', '565695', '10.4389', 1584078180000],
#  ['565695', '574000', '564500', '566972', '9.3934', 1584078240000],
#  ['568010', '572999', '566070', '567000', '9.4969', 1584078300000],
#  ['567003', '568012', '562502', '565098', '7.5271', 1584078360000],
#  ['562515', '565460', '560011', '564487', '3.8085', 1584078420000],
#  ['564487', '564487', '558001', '563868', '5.7665', 1584078480000],
#  ['563221', '564499', '556010', '562023', '7.6641', 1584078540000],
#  ['561094', '564000', '559434', '564000', '5.8275', 1584078600000],
#  ['560344', '564499', '560000', '560752', '4.2711', 1584078660000],
#  ['560953', '562000', '560953', '561366', '1.4945', 1584078720000],
#  ['561360', '562344', '560955', '562004', '3.1106', 1584078780000],
#  ['562003', '562499', '562001', '562001', '0.9978', 1584078840000],
#  ['562001', '562490', '560006', '561999', '2.2769', 1584078900000],
#  ['560006', '560012', '560006', '560011', '0.8639', 1584078960000],
#  ['560007', '562004', '560006', '562000', '3.5661', 1584079020000],
#  ['562000', '562000', '558800', '558800', '3.4765', 1584079080000],
#  ['558800', '564994', '558800', '560384', '6.1752', 1584079140000],
#  ['560384', '568000', '558800', '560391', '5.7678', 1584079200000],
#  ['568000', '568000', '560257', '560263', '6.4380', 1584079260000],
#  ['560263', '560263', '557000', '557006', '5.1515', 1584079320000],
#  ['557006', '565000', '557006', '557055', '4.5346', 1584079380000],
#  ['557055', '558300', '556037', '557900', '7.6235', 1584079440000],
#  ['558000', '561994', '558000', '560002', '2.5547', 1584079500000],
#  ['560002', '562000', '558002', '560003', '7.5999', 1584079560000],
#  ['560000', '560000', '558000', '558003', '1.2603', 1584079620000],
#  ['558002', '559498', '558002', '558018', '0.6155', 1584079680000],
#  ['559498', '562426', '558016', '562400', '6.4340', 1584079740000],
#  ['561998', '563000', '561779', '562148', '4.2360', 1584079800000],
#  ['562149', '565988', '561190', '565003', '6.4128', 1584079860000],
#  ['565988', '570001', '565003', '568271', '8.8061', 1584079920000],
#  ['568271', '569767', '568162', '568999', '2.6906', 1584079980000],
#  ['568999', '572108', '568999', '571999', '5.4908', 1584080040000],
#  ['572002', '579999', '569459', '577074', '6.3683', 1584080100000],
#  ['573466', '582002', '571214', '574767', '15.5459', 1584080160000],
#  ['570004', '576010', '569999', '570048', '3.2172', 1584080220000],
#  ['570033', '571424', '569214', '570000', '5.0733', 1584080280000],
#  ['570000', '571000', '566186', '570999', '2.0100', 1584080340000],
#  ['569762', '574272', '567999', '571429', '3.9378', 1584080400000],
#  ['571430', '580000', '569999', '571925', '5.6882', 1584080460000],
#  ['571926', '576094', '571926', '573003', '1.8531', 1584080520000],
#  ['573004', '574001', '571926', '572000', '3.0959', 1584080580000],
#  ['571981', '578911', '571981', '573015', '2.4558', 1584080640000],
#  ['573016', '576495', '573005', '573005', '1.5239', 1584080700000],
#  ['573005', '575610', '573005', '573500', '4.7553', 1584080760000],
#  ['573505', '576963', '573500', '576963', '2.1869', 1584080820000],
#  ['576838', '582123', '576838', '577100', '11.6550', 1584080880000],
#  ['577101', '578664', '577100', '578226', '1.3239', 1584080940000],
#  ['577203', '579300', '577201', '577217', '4.5118', 1584081000000],
#  ['577219', '581500', '577219', '581019', '1.9435', 1584081060000],
#  ['581019', '581410', '577206', '577206', '13.1975', 1584081120000],
#  ['577206', '577851', '573514', '576000', '8.6116', 1584081180000],
#  ['576703', '576995', '572755', '572756', '7.9785', 1584081240000],
#  ['572129', '572756', '564011', '570000', '6.3044', 1584081300000],
#  ['569999', '572000', '566854', '572000', '3.8139', 1584081360000],
#  ['572010', '576005', '570005', '572146', '2.1697', 1584081420000],
#  ['572428', '575698', '572327', '572432', '1.0665', 1584081480000],
#  ['573999', '576118', '573999', '574000', '7.0555', 1584081540000],
#  ['574000', '574890', '570271', '570288', '5.4792', 1584081600000],
#  ['574889', '575009', '571000', '575009', '0.3962', 1584081660000],
#  ['575008', '576000', '571023', '572012', '1.2291', 1584081720000],
#  ['572017', '580000', '572017', '576999', '9.1745', 1584081780000],
#  ['576999', '577000', '575008', '576000', '4.3208', 1584081840000],
#  ['576000', '576500', '574000', '575008', '2.8548', 1584081900000],
#  ['574001', '574001', '571510', '571510', '3.2551', 1584081960000],
#  ['571510', '576627', '571000', '571285', '10.2503', 1584082020000],
#  ['571285', '571554', '566839', '571121', '5.3944', 1584082080000],
#  ['567207', '571120', '567206', '568143', '1.2477', 1584082140000],
#  ['567211', '568143', '567211', '568000', '0.6118', 1584082200000],
#  ['568001', '569000', '567084', '567085', '2.6967', 1584082260000],
#  ['567085', '567085', '565000', '565000', '4.3388', 1584082320000],
#  ['564011', '568000', '564000', '564010', '2.2345', 1584082380000],
#  ['564010', '574800', '564010', '574800', '3.2657', 1584082440000],
#  ['570080', '571000', '564500', '570003', '2.2942', 1584082500000],
#  ['570002', '570002', '567310', '568168', '0.5246', 1584082560000],
#  ['567435', '573004', '567434', '573004', '2.1511', 1584082620000],
#  ['573007', '579999', '573007', '579999', '6.5442', 1584082680000],
#  ['577351', '578995', '576010', '577374', '2.8364', 1584082740000],
#  ['577373', '577374', '570000', '571989', '7.3710', 1584082800000],
#  ['571987', '571987', '568012', '569325', '14.6618', 1584082860000],
#  ['569322', '570000', '568012', '570000', '7.5754', 1584082920000],
#  ['570000', '575000', '569751', '569751', '2.9143', 1584082980000],
#  ['569330', '571547', '569330', '570630', '1.8260', 1584083040000],
#  ['570629', '571269', '569005', '569043', '0.1575', 1584083100000],
#  ['569073', '569144', '569073', '569144', '0.0450', 1584083160000],
#  ['570058', '571447', '568001', '568004', '1.6999', 1584083220000],
#  ['568002', '570083', '564512', '567474', '7.3331', 1584083280000],
#  ['567474', '569020', '564901', '569020', '1.0989', 1584083340000],
#  ['569020', '569020', '567777', '567778', '1.7700', 1584083400000],
#  ['567778', '570000', '567777', '567785', '0.2604', 1584083460000],
#  ['567791', '570000', '567780', '567783', '1.2178', 1584083520000],
#  ['569994', '569999', '568409', '568512', '0.1404', 1584083580000],
#  ['569999', '572315', '569999', '572315', '3.7843', 1584083640000],
#  ['572911', '575000', '570001', '571898', '2.2137', 1584083700000],
#  ['571900', '572195', '570703', '572100', '2.8896', 1584083760000],
#  ['571398', '572195', '570964', '572195', '2.4900', 1584083820000],
#  ['572201', '575000', '572201', '573985', '5.5428', 1584083880000],
#  ['573988', '576000', '573988', '576000', '8.6678', 1584083940000],
#  ['575052', '576000', '574371', '575999', '3.5613', 1584084000000],
#  ['575995', '576000', '575100', '575100', '2.6877', 1584084060000],
#  ['575101', '576007', '575000', '575080', '3.4677', 1584084120000],
#  ['575079', '575079', '573000', '573999', '4.8396', 1584084180000],
#  ['573999', '574746', '573002', '573757', '2.7607', 1584084240000],
#  ['573757', '575999', '573012', '575810', '5.3732', 1584084300000],
#  ['575810', '576946', '575001', '575669', '10.3234', 1584084360000],
#  ['575005', '576868', '575001', '575003', '2.1592', 1584084420000],
#  ['575003', '576700', '575002', '576693', '3.4506', 1584084480000],
#  ['575050', '576699', '575045', '575555', '1.8160', 1584084540000],
#  ['575102', '575555', '571500', '573498', '14.5188', 1584084600000],
#  ['573497', '575256', '572000', '572281', '1.4186', 1584084660000],
#  ['573812', '574645', '571607', '571607', '3.3311', 1584084720000],
#  ['572183', '573844', '572183', '572184', '0.2314', 1584084780000],
#  ['572188', '574800', '572188', '574800', '5.7498', 1584084840000],
#  ['574800', '576700', '574434', '574435', '11.4636', 1584084900000],
#  ['574435', '576700', '573444', '573444', '5.5108', 1584084960000],
#  ['574437', '576693', '573444', '573444', '0.9579', 1584085020000],
#  ['574469', '575102', '573445', '574459', '3.9064', 1584085080000],
#  ['574459', '576690', '574459', '574586', '5.8682', 1584085140000],
#  ['574598', '576554', '574597', '574667', '1.4954', 1584085200000],
#  ['574670', '576500', '574670', '576481', '3.7835', 1584085260000],
#  ['576463', '576698', '576463', '576698', '2.7585', 1584085320000],
#  ['576697', '576699', '576478', '576699', '6.9497', 1584085380000],
#  ['576696', '576699', '576478', '576499', '1.4513', 1584085440000],
#  ['576478', '576699', '574672', '575226', '2.0995', 1584085500000],
#  ['575228', '576698', '574670', '575479', '1.0793', 1584085560000],
#  ['576690', '576698', '575479', '575905', '1.2988', 1584085620000],
#  ['576000', '576000', '575905', '576000', '0.8348', 1584085680000],
#  ['576000', '578000', '576000', '578000', '5.4125', 1584085740000],
#  ['578000', '579500', '577825', '579500', '10.7239', 1584085800000],
#  ['579500', '587997', '579500', '587997', '9.6417', 1584085860000],
#  ['584511', '590000', '577968', '586403', '12.1808', 1584085920000],
#  ['586407', '600000', '586407', '596002', '11.3673', 1584085980000],
#  ['596002', '599964', '593016', '595801', '5.0550', 1584086040000],
#  ['595805', '595805', '588429', '591977', '6.8680', 1584086100000],
#  ['591969', '592000', '591750', '592000', '3.9513', 1584086160000],
#  ['592000', '599897', '592000', '598048', '4.4858', 1584086220000],
#  ['598053', '598547', '597896', '598101', '5.5877', 1584086280000],
#  ['598101', '599556', '595915', '597109', '5.0573', 1584086340000],
#  ['597109', '600000', '596999', '599993', '7.3457', 1584086400000],
#  ['599993', '604586', '599992', '604581', '8.4093', 1584086460000],
#  ['604577', '607440', '602273', '605052', '5.1837', 1584086520000],
#  ['605052', '607440', '602016', '607439', '8.5062', 1584086580000],
#  ['607439', '612008', '607439', '612008', '7.5118', 1584086640000],
#  ['612008', '618000', '612008', '615980', '14.4211', 1584086700000],
#  ['615311', '615982', '604010', '606160', '10.0001', 1584086760000],
#  ['606160', '610000', '604012', '608996', '12.5390', 1584086820000],
#  ['608995', '609000', '606000', '606001', '4.2460', 1584086880000],
#  ['606000', '606000', '600056', '604674', '6.0362', 1584086940000],
#  ['604661', '604964', '600000', '600001', '9.9452', 1584087000000],
#  ['600000', '603875', '597000', '597001', '10.6719', 1584087060000],
#  ['597001', '597012', '589000', '589001', '5.8455', 1584087120000],
#  ['589003', '590002', '589003', '590002', '4.4644', 1584087180000],
#  ['590002', '591000', '589216', '589236', '7.5925', 1584087240000],
#  ['589258', '595040', '589235', '594050', '4.6464', 1584087300000],
#  ['594050', '594659', '592084', '592339', '3.4860', 1584087360000],
#  ['592863', '594059', '592387', '593019', '1.4620', 1584087420000],
#  ['594056', '601000', '593020', '597294', '4.1035', 1584087480000],
#  ['599499', '605721', '596021', '596972', '12.0070', 1584087540000],
#  ['596971', '600000', '596967', '599991', '2.8924', 1584087600000],
#  ['599991', '599991', '598500', '598521', '4.9335', 1584087660000],
#  ['598500', '599000', '598326', '598551', '2.3762', 1584087720000],
#  ['599000', '605700', '599000', '605700', '9.1438', 1584087780000],
#  ['605695', '605698', '600037', '603057', '2.2608', 1584087840000],
#  ['603059', '603336', '600002', '601568', '2.5285', 1584087900000],
#  ['600246', '600964', '599952', '600000', '3.2911', 1584087960000],
#  ['600002', '602999', '600002', '601787', '6.4764', 1584088020000],
#  ['601025', '604994', '601025', '602005', '3.8736', 1584088080000],
#  ['602005', '602300', '600000', '600024', '5.8404', 1584088140000],
#  ['600620', '600621', '600000', '600003', '1.9927', 1584088200000],
#  ['600005', '600619', '598000', '598000', '5.2967', 1584088260000],
#  ['598001', '598003', '595000', '595000', '5.6230', 1584088320000],
#  ['595002', '595002', '590001', '592001', '5.6566', 1584088380000],
#  ['592000', '592001', '584205', '586298', '6.0249', 1584088440000],
#  ['584205', '588010', '583096', '587331', '2.7397', 1584088500000],
#  ['586598', '587104', '584123', '584123', '1.3090', 1584088560000],
#  ['584124', '584892', '580069', '583796', '4.4463', 1584088620000],
#  ['580072', '583781', '580000', '581225', '6.2381', 1584088680000],
#  ['581225', '587835', '581000', '584205', '11.5560', 1584088740000],
#  ['584205', '588808', '581000', '587753', '10.4970', 1584088800000],
#  ['586827', '590824', '586827', '587009', '7.9032', 1584088860000],
#  ['587009', '587010', '587009', '587009', '2.8795', 1584088920000],
#  ['587009', '587010', '585035', '586522', '3.5103', 1584088980000],
#  ['587007', '587007', '586010', '586991', '2.0443', 1584089040000],
#  ['586989', '586989', '583037', '584081', '4.4806', 1584089100000],
#  ['584081', '584081', '580012', '582997', '5.1460', 1584089160000],
#  ['582525', '582525', '580000', '580000', '2.6174', 1584089220000],
#  ['580000', '582301', '580000', '580348', '1.6207', 1584089280000],
#  ['580350', '582291', '580348', '580753', '0.6582', 1584089340000],
#  ['580353', '582296', '580352', '582296', '0.9208', 1584089400000],
#  ['582296', '582296', '580812', '582295', '0.6841', 1584089460000],
#  ['582295', '586073', '582295', '586073', '0.9751', 1584089520000],
#  ['586073', '586785', '584697', '586755', '0.8365', 1584089580000],
#  ['586685', '586685', '584699', '584699', '3.1562', 1584089640000],
#  ['584991', '584991', '584000', '584644', '1.2539', 1584089700000],
#  ['584000', '584635', '580500', '583797', '1.6209', 1584089760000],
#  ['583799', '583913', '581854', '583899', '0.5323', 1584089820000],
#  ['583899', '585748', '581869', '585747', '1.1691', 1584089880000],
#  ['585001', '587481', '581969', '584147', '1.8517', 1584089940000],
#  ['583980', '584997', '582849', '584018', '0.6135', 1584090000000],
#  ['584984', '585174', '584026', '584078', '5.0961', 1584090060000],
#  ['585160', '587473', '585160', '586907', '0.1906', 1584090120000],
#  ['586907', '587411', '584557', '586898', '2.8630', 1584090180000],
#  ['586898', '586898', '585019', '585019', '1.8740', 1584090240000],
#  ['586895', '587000', '586470', '586869', '1.2358', 1584090300000],
#  ['585288', '586711', '585180', '586711', '2.1272', 1584090360000],
#  ['585240', '587131', '585240', '587131', '0.2131', 1584090420000],
#  ['587376', '587500', '586507', '587500', '2.5922', 1584090480000],
#  ['587747', '587749', '585500', '586003', '2.1863', 1584090540000],
#  ['586005', '587468', '586003', '586003', '0.9815', 1584090600000],
#  ['586005', '587355', '584018', '584018', '7.2959', 1584090660000],
#  ['584546', '592000', '584546', '591999', '7.4060', 1584090720000],
#  ['591987', '595000', '591967', '595000', '1.8686', 1584090780000],
#  ['595000', '600012', '593261', '599994', '10.5874', 1584090840000],
#  ['598057', '601139', '592409', '594245', '8.5896', 1584090900000],
#  ['594245', '596000', '588017', '590075', '7.1191', 1584090960000],
#  ['590072', '594904', '590061', '594860', '1.6375', 1584091020000],
#  ['592813', '594855', '591044', '592223', '2.4851', 1584091080000],
#  ['592224', '592224', '589061', '589260', '3.5968', 1584091140000],
#  ['589791', '589791', '584591', '587998', '5.9147', 1584091200000],
#  ['587999', '587999', '585030', '585986', '2.6990', 1584091260000],
#  ['586205', '593449', '586205', '593449', '10.9439', 1584091320000],
#  ['590647', '590787', '588012', '588221', '0.6240', 1584091380000],
#  ['589992', '590957', '589992', '590013', '0.8203', 1584091440000],
#  ['590013', '593446', '590000', '593444', '2.8047', 1584091500000],
#  ['593444', '593444', '591197', '592999', '1.1227', 1584091560000],
#  ['592992', '593000', '591368', '591458', '7.4179', 1584091620000],
#  ['591393', '591393', '590001', '590394', '0.3084', 1584091680000],
#  ['590404', '607000', '590404', '590724', '19.8009', 1584091740000],
#  ['590720', '590727', '590000', '590000', '14.8432', 1584091800000],
#  ['590618', '590618', '590617', '590618', '2.1907', 1584091860000],
#  ['590617', '590618', '590617', '590618', '3.3430', 1584091920000],
#  ['590618', '590618', '590617', '590618', '1.7113', 1584091980000],
#  ['590618', '604100', '590618', '594302', '14.3755', 1584092040000],
#  ['594959', '597980', '593000', '593885', '7.5257', 1584092100000],
#  ['594780', '594963', '593025', '594963', '1.9934', 1584092160000],
#  ['594963', '595736', '594963', '595736', '1.0822', 1584092220000],
#  ['597987', '601000', '596800', '599907', '1.4351', 1584092280000],
#  ['598999', '603000', '598998', '599064', '2.2878', 1584092340000],
#  ['601008', '601016', '598769', '598999', '2.7142', 1584092400000],
#  ['599000', '605000', '599000', '601519', '4.3666', 1584092460000],
#  ['603869', '606155', '602018', '605086', '4.3606', 1584092520000],
#  ['605001', '608675', '605000', '606016', '2.8817', 1584092580000],
#  ['606016', '606492', '601008', '603790', '9.6104', 1584092640000],
#  ['605186', '606307', '601120', '601137', '4.6323', 1584092700000],
#  ['602796', '602797', '601125', '602183', '2.3892', 1584092760000],
#  ['601999', '605335', '601999', '605334', '1.4723', 1584092820000],
#  ['605333', '610000', '605330', '608413', '9.7271', 1584092880000],
#  ['608413', '610000', '608413', '610000', '4.9180', 1584092940000],
#  ['609999', '619368', '605337', '611503', '22.1422', 1584093000000],
#  ['610999', '620000', '601017', '619163', '22.0220', 1584093060000],
#  ['619645', '619999', '614544', '618974', '15.0518', 1584093120000],
#  ['618000', '623000', '617978', '623000', '10.3951', 1584093180000],
#  ['622999', '623000', '605555', '620011', '27.5090', 1584093240000],
#  ['620015', '629000', '620015', '623837', '11.9825', 1584093300000],
#  ['623487', '628998', '621025', '621900', '22.1643', 1584093360000],
#  ['621900', '625282', '621900', '624989', '5.2347', 1584093420000],
#  ['625000', '630583', '624992', '626803', '10.0106', 1584093480000],
#  ['629689', '629689', '625225', '625787', '10.0275', 1584093540000],
#  ['625225', '626784', '621026', '625007', '9.2614', 1584093600000],
#  ['626784', '626784', '622020', '624970', '7.8491', 1584093660000],
#  ['624911', '624911', '622035', '623172', '11.0817', 1584093720000],
#  ['623988', '630000', '623172', '629000', '11.8007', 1584093780000],
#  ['628991', '628992', '624300', '625007', '5.5226', 1584093840000],
#  ['625013', '628000', '625000', '627689', '5.6830', 1584093900000],
#  ['626604', '626737', '622000', '625325', '2.7491', 1584093960000],
#  ['625324', '625325', '622323', '622323', '7.8838', 1584094020000],
#  ['625300', '625325', '620011', '623066', '10.2629', 1584094080000],
#  ['623066', '625000', '616011', '619149', '8.6053', 1584094140000],
#  ['621224', '625000', '618976', '621400', '9.9946', 1584094200000],
#  ['621400', '624993', '615000', '617001', '7.0682', 1584094260000],
#  ['616999', '617000', '615000', '617000', '5.3052', 1584094320000],
#  ['616999', '620291', '616000', '620290', '6.5984', 1584094380000],
#  ['620445', '620999', '618980', '620440', '9.8069', 1584094440000],
#  ['620440', '620969', '617746', '619973', '3.5876', 1584094500000],
#  ['617360', '617741', '616800', '616800', '1.0176', 1584094560000],
#  ['616800', '616800', '612000', '614912', '4.8860', 1584094620000],
#  ['614912', '621739', '613040', '621739', '4.8571', 1584094680000],
#  ['620800', '624230', '620800', '623177', '5.3204', 1584094740000],
#  ['623182', '630004', '623178', '630004', '9.0066', 1584094800000],
#  ['630544', '631000', '628003', '630000', '9.2613', 1584094860000],
#  ['630000', '631881', '628000', '630478', '15.1839', 1584094920000],
#  ['630468', '630468', '628000', '629911', '3.2011', 1584094980000],
#  ['629881', '632000', '629881', '631576', '3.9945', 1584095040000],
#  ['631575', '632000', '630756', '632000', '4.0029', 1584095100000],
#  ['631998', '632500', '631575', '631576', '4.4383', 1584095160000],
#  ['631575', '632800', '630656', '632770', '7.3871', 1584095220000],
#  ['632740', '632741', '628000', '628487', '6.3021', 1584095280000],
#  ['628487', '629908', '625000', '628993', '3.5924', 1584095340000],
#  ['628005', '630000', '628005', '629594', '2.0566', 1584095400000],
#  ['629008', '632800', '629008', '632799', '2.5707', 1584095460000],
#  ['632800', '639981', '629460', '634000', '8.6619', 1584095520000],
#  ['634000', '634875', '632220', '634266', '1.1325', 1584095580000],
#  ['634267', '639000', '634267', '635027', '5.7742', 1584095640000],
#  ['635028', '638999', '635000', '635000', '9.5552', 1584095700000],
#  ['635000', '635001', '630000', '630001', '4.7260', 1584095760000],
#  ['630001', '632120', '630001', '631000', '1.1510', 1584095820000],
#  ['631000', '631000', '629082', '629086', '2.6179', 1584095880000],
#  ['629087', '629091', '624000', '624004', '8.1610', 1584095940000],
#  ['624078', '628300', '624078', '625647', '9.1133', 1584096000000],
#  ['625646', '628059', '618000', '623453', '11.7073', 1584096060000],
#  ['623452', '623453', '618005', '620064', '7.1244', 1584096120000],
#  ['621318', '621318', '619742', '619999', '3.7452', 1584096180000],
#  ['619999', '619999', '613001', '617904', '8.9857', 1584096240000],
#  ['617903', '617911', '613003', '615316', '10.3988', 1584096300000],
#  ['615316', '617524', '615000', '617524', '15.7067', 1584096360000],
#  ['617523', '622466', '616110', '622369', '3.4133', 1584096420000],
#  ['622369', '622369', '619959', '621402', '2.5980', 1584096480000],
#  ['621402', '621997', '621235', '621333', '1.4018', 1584096540000],
#  ['621335', '623000', '621329', '621390', '2.6538', 1584096600000],
#  ['622272', '622275', '619928', '619928', '3.8146', 1584096660000],
#  ['620016', '621188', '619724', '621188', '5.0331', 1584096720000],
#  ['620000', '621786', '620000', '620004', '0.2705', 1584096780000],
#  ['620033', '621069', '616701', '616701', '4.9492', 1584096840000],
#  ['616014', '619794', '615500', '618011', '1.1724', 1584096900000],
#  ['618799', '620000', '618000', '619882', '2.9803', 1584096960000],
#  ['619882', '621362', '618661', '621168', '1.1602', 1584097020000],
#  ['621361', '624318', '621361', '624314', '4.0986', 1584097080000],
#  ['624314', '624317', '621605', '622309', '1.6496', 1584097140000],
#  ['624062', '624075', '619331', '619456', '6.4907', 1584097200000],
#  ['619449', '619449', '616309', '616312', '5.0485', 1584097260000],
#  ['616312', '621605', '616310', '616489', '2.1970', 1584097320000],
#  ['617365', '617365', '613000', '613201', '4.6354', 1584097380000],
#  ['613000', '613001', '600500', '601056', '20.9124', 1584097440000],
#  ['601056', '606091', '600000', '602647', '16.9673', 1584097500000],
#  ['603220', '603423', '600000', '600000', '9.3795', 1584097560000],
#  ['600001', '600001', '591221', '591773', '16.9444', 1584097620000],
#  ['593224', '597288', '591299', '597287', '9.9129', 1584097680000],
#  ['597287', '597288', '593500', '596341', '9.4849', 1584097740000],
#  ['596340', '605022', '595601', '600683', '4.1692', 1584097800000],
#  ['601001', '607799', '601001', '606301', '6.4490', 1584097860000],
#  ['606302', '607744', '606302', '607298', '6.8204', 1584097920000],
#  ['607298', '607298', '607000', '607002', '7.2884', 1584097980000],
#  ['607002', '607002', '605000', '605001', '8.8291', 1584098040000],
#  ['606200', '606995', '605002', '606700', '2.1753', 1584098100000],
#  ['606706', '613273', '606706', '611279', '6.8084', 1584098160000],
#  ['613156', '613156', '607251', '607253', '4.0732', 1584098220000],
#  ['607260', '612000', '607251', '608232', '2.8469', 1584098280000],
#  ['608240', '611999', '608228', '608230', '0.8314', 1584098340000],
#  ['608230', '608230', '606806', '606807', '7.2282', 1584098400000],
#  ['606806', '611126', '606700', '608241', '9.2943', 1584098460000],
#  ['608241', '610039', '606984', '610038', '2.6239', 1584098520000],
#  ['610040', '610041', '607731', '608235', '8.4998', 1584098580000],
#  ['607737', '614900', '607078', '607078', '10.8582', 1584098640000],
#  ['607078', '608995', '606001', '608995', '1.7972', 1584098700000],
#  ['608997', '610999', '608996', '610001', '4.0226', 1584098760000],
#  ['609536', '609536', '607417', '609524', '1.3008', 1584098820000],
#  ['609998', '610429', '609220', '610428', '1.9918', 1584098880000],
#  ['610428', '610429', '608088', '608088', '6.3999', 1584098940000],
#  ['609199', '611174', '609199', '611174', '6.7793', 1584099000000],
#  ['611173', '615000', '611173', '614999', '5.2703', 1584099060000],
#  ['615000', '615527', '611211', '615526', '2.6740', 1584099120000],
#  ['615526', '615526', '614906', '614908', '2.2451', 1584099180000],
#  ['614908', '619788', '614906', '619497', '21.6948', 1584099240000],
#  ['619411', '623000', '618827', '622881', '10.1983', 1584099300000],
#  ['622881', '622881', '617162', '619998', '4.2230', 1584099360000],
#  ['619999', '622998', '619108', '620006', '1.3949', 1584099420000],
#  ['620005', '620007', '618000', '618016', '5.3500', 1584099480000],
#  ['618027', '618062', '616019', '616019', '7.6818', 1584099540000],
#  ['617000', '620245', '616620', '619039', '5.1457', 1584099600000],
#  ['619042', '619972', '615116', '615474', '4.4996', 1584099660000],
#  ['615472', '619161', '615470', '617952', '6.0708', 1584099720000],
# ...
#  ['629147', '630800', '629146', '630026', '1.0461', 1584103560000],
#  ['630027', '631000', '630026', '630032', '3.3088', 1584103620000],
#  ['630032', '630032', '622984', '625730', '9.9044', 1584103680000],
#  ['625730', '628992', '625729', '625743', '2.6835', 1584103740000],
#  ['628191', '628191', '625748', '627494', '1.6048', 1584103800000],
#  ['627495', '627790', '625053', '625054', '2.1575', 1584103860000],
#  ['624228', '625045', '622984', '622984', '4.3144', 1584103920000],
#  ['622984', '622984', '615002', '617413', '11.3357', 1584103980000],
#  ['617414', '619600', '616889', '618124', '3.8810', 1584104040000],
#  ['618124', '619593', '617111', '619592', '2.8476', 1584104100000],
#  ['619593', '627165', '619593', '623027', '2.9130', 1584104160000],
#  ['623027', '623027', '620992', '620992', '3.5091', 1584104220000],
#  ['620988', '622011', '620182', '620220', '3.8972', 1584104280000],
#  ['620339', '624290', '620339', '624290', '2.6308', 1584104340000],
#  ['624281', '626460', '622040', '624360', '1.1752', 1584104400000],
#  ['625499', '627171', '624385', '625135', '4.9914', 1584104460000],
#  ['625132', '625132', '622000', '622005', '2.0802', 1584104520000],
#  ['622006', '623247', '622000', '623192', '1.1681', 1584104580000],
#  ['623192', '623195', '622006', '622006', '0.7756', 1584104640000],
#  ['622006', '623000', '621172', '621281', '0.7155', 1584104700000],
#  ['621280', '621999', '620401', '621973', '1.8387', 1584104760000],
#  ['620474', '621967', '619200', '619203', '4.3104', 1584104820000],
#  ['619208', '619208', '616000', '616020', '3.6672', 1584104880000],
#  ['616020', '621000', '615529', '621000', '9.4502', 1584104940000],
#  ['621955', '623192', '619999', '623191', '7.5517', 1584105000000],
#  ['623191', '623500', '623191', '623500', '2.0473', 1584105060000],
#  ['623499', '627999', '623499', '627999', '3.4344', 1584105120000],
#  ['628000', '629600', '627998', '629599', '2.1360', 1584105180000],
#  ['629599', '630000', '626425', '627155', '2.6604', 1584105240000],
#  ['627175', '631000', '627175', '630305', '10.7936', 1584105300000],
#  ['630306', '633879', '630306', '632618', '8.7897', 1584105360000],
#  ['631999', '633254', '631073', '633242', '4.2614', 1584105420000],
#  ['633242', '633900', '632094', '633300', '10.4537', 1584105480000],
#  ['633070', '633900', '632655', '633900', '4.8426', 1584105540000],
#  ['634256', '638000', '633901', '635881', '11.9885', 1584105600000],
#  ['638000', '639987', '635395', '636000', '3.4252', 1584105660000],
#  ['636000', '636974', '634264', '634986', '12.7766', 1584105720000],
#  ['634986', '636002', '632012', '632815', '9.3490', 1584105780000],
#  ['633598', '634006', '628191', '629999', '10.8187', 1584105840000],
#  ['629999', '633000', '629999', '631502', '10.5663', 1584105900000],
#  ['631584', '632999', '630002', '632200', '1.3392', 1584105960000],
#  ['633000', '634007', '631606', '634007', '3.1845', 1584106020000],
#  ['633001', '639493', '633000', '639493', '3.7743', 1584106080000],
#  ['637891', '644994', '637891', '642996', '21.6587', 1584106140000],
#  ['644002', '644991', '635175', '638675', '26.8241', 1584106200000],
#  ['638678', '645000', '635177', '643991', '7.0583', 1584106260000],
#  ['643990', '659987', '643990', '652315', '21.2318', 1584106320000],
#  ['652629', '669995', '652628', '665002', '31.0818', 1584106380000],
#  ['665003', '671029', '664963', '669214', '25.6929', 1584106440000],
#  ['669994', '669998', '652000', '661041', '35.4579', 1584106500000],
#  ['661041', '664321', '655669', '660000', '11.5086', 1584106560000],
#  ['660000', '660145', '652015', '658001', '17.2819', 1584106620000],
#  ['658002', '658005', '647410', '654503', '18.3619', 1584106680000],
#  ['654503', '658000', '654480', '656001', '6.3212', 1584106740000],
#  ['656001', '656001', '646256', '647512', '16.2994', 1584106800000],
#  ['647194', '647195', '636000', '639991', '22.7592', 1584106860000],
#  ['639992', '647697', '639992', '644007', '14.2266', 1584106920000],
#  ['647684', '647684', '642000', '644000', '5.4277', 1584106980000],
#  ['644000', '644000', '638000', '638000', '15.5175', 1584107040000],
#  ['639997', '647998', '639582', '647998', '13.6086', 1584107100000],
#  ['645006', '649954', '644720', '646268', '10.5347', 1584107160000],
#  ['646297', '648000', '644746', '648000', '2.7249', 1584107220000],
#  ['648597', '653000', '647903', '651485', '6.5114', 1584107280000],
#  ['651487', '653000', '649514', '649514', '10.3458', 1584107340000],
#  ['649514', '649514', '645982', '646001', '4.7073', 1584107400000],
#  ['647345', '647507', '646001', '646102', '3.7593', 1584107460000],
#  ['647441', '647441', '644000', '646106', '2.3937', 1584107520000],
#  ['646107', '647103', '642157', '642157', '4.3304', 1584107580000],
#  ['642158', '642984', '642000', '642165', '2.7606', 1584107640000],
#  ['642165', '643349', '642157', '642157', '4.5235', 1584107700000],
#  ['642159', '647998', '638107', '639997', '16.7321', 1584107760000],
#  ['640000', '641522', '637053', '639304', '15.2327', 1584107820000],
#  ['639303', '640009', '631000', '634199', '17.7018', 1584107880000],
#  ['631004', '634625', '628010', '633600', '16.1060', 1584107940000],
#  ['633598', '636010', '633598', '636009', '2.8867', 1584108000000],
#  ['636009', '640000', '636009', '637101', '9.8389', 1584108060000],
#  ['638986', '641398', '638002', '638954', '8.0901', 1584108120000],
#  ['638954', '640000', '638954', '639900', '2.9301', 1584108180000],
#  ['639999', '642355', '639999', '642354', '9.5157', 1584108240000],
#  ['642355', '644975', '637496', '637496', '26.1412', 1584108300000],
#  ['637987', '646988', '637987', '639994', '3.5079', 1584108360000],
#  ['639101', '642000', '637434', '640890', '4.8653', 1584108420000],
#  ['640890', '641496', '640000', '640000', '2.8260', 1584108480000],
#  ['640000', '641500', '640000', '640011', '4.5146', 1584108540000],
#  ['641374', '641374', '640005', '640056', '3.3991', 1584108600000],
#  ['640055', '642172', '639001', '642172', '7.3551', 1584108660000],
#  ['639558', '647478', '639003', '643250', '4.9102', 1584108720000],
#  ['645976', '646000', '643251', '644995', '2.4362', 1584108780000],
#  ['644994', '646000', '644204', '646000', '2.0799', 1584108840000],
#  ['646005', '648998', '646000', '648998', '2.8734', 1584108900000],
#  ['648998', '658881', '647965', '652012', '9.7015', 1584108960000],
#  ['652012', '655998', '650000', '651999', '5.4371', 1584109020000],
#  ['652005', '659000', '652005', '653779', '9.5390', 1584109080000],
#  ['653888', '659500', '653888', '658003', '12.5243', 1584109140000],
#  ['658002', '664000', '658000', '660010', '18.6634', 1584109200000],
#  ['660020', '660776', '656730', '656730', '10.1685', 1584109260000],
#  ['656013', '660000', '656013', '656279', '15.2004', 1584109320000],
#  ['656279', '663000', '656279', '660008', '8.7514', 1584109380000],
#  ['662998', '662999', '658999', '660004', '3.9034', 1584109440000],
#  ['660005', '660150', '655866', '655866', '11.5236', 1584109500000],
#  ['655869', '659000', '655869', '658998', '7.0542', 1584109560000],
#  ['658638', '660150', '656555', '658000', '12.5526', 1584109620000],
#  ['657260', '660049', '657259', '659706', '3.9790', 1584109680000],
#  ['660005', '662000', '659703', '660093', '4.4917', 1584109740000],
#  ['660094', '661898', '655866', '661600', '9.4969', 1584109800000],
#  ['660094', '661603', '660000', '660000', '10.2542', 1584109860000],
#  ['660005', '661000', '658000', '658500', '5.9577', 1584109920000],
#  ['658600', '659999', '658000', '659001', '3.3047', 1584109980000],
#  ['659997', '659998', '648000', '655302', '12.3766', 1584110040000],
#  ['655303', '657840', '648000', '654011', '13.6088', 1584110100000],
#  ['654999', '659899', '654523', '656617', '3.6504', 1584110160000],
#  ['656700', '659898', '656700', '656994', '6.0432', 1584110220000],
#  ['658996', '658998', '656994', '657000', '0.6134', 1584110280000],
#  ['657000', '657994', '650000', '654003', '1.2732', 1584110340000],
#  ['655997', '655998', '650000', '652993', '5.7583', 1584110400000],
#  ['652993', '652993', '646726', '646728', '6.9145', 1584110460000],
#  ['646727', '646730', '634978', '642279', '16.5788', 1584110520000],
#  ['642282', '642282', '634211', '634211', '10.4372', 1584110580000],
#  ['634211', '634211', '632525', '634211', '14.5083', 1584110640000],
#  ['634211', '636026', '628683', '629800', '16.1276', 1584110700000],
#  ['631493', '633630', '625963', '625963', '20.2523', 1584110760000],
#  ['625962', '629672', '625100', '625891', '11.1222', 1584110820000],
#  ['625891', '629900', '625271', '627000', '8.5826', 1584110880000],
#  ['629571', '629571', '625263', '625264', '6.8676', 1584110940000],
#  ['625265', '627764', '622800', '627764', '12.8688', 1584111000000],
#  ['628000', '629001', '627999', '629000', '9.5373', 1584111060000],
#  ['629215', '629223', '624000', '628001', '9.9650', 1584111120000],
#  ['627978', '627978', '621023', '621023', '7.1189', 1584111180000],
#  ['621023', '627101', '610117', '617486', '18.2547', 1584111240000],
#  ['617481', '617484', '609503', '609503', '16.1053', 1584111300000],
#  ['609503', '609503', '600001', '601233', '26.8543', 1584111360000],
#  ['601233', '608000', '600091', '605800', '14.6999', 1584111420000],
#  ['607983', '608010', '603000', '604100', '10.8433', 1584111480000],
#  ['604100', '616000', '603000', '608281', '10.8345', 1584111540000],
#  ['612010', '617000', '608300', '615466', '6.0545', 1584111600000],
#  ['613008', '617000', '613008', '613500', '7.8409', 1584111660000],
#  ['614001', '614990', '605000', '605500', '11.4243', 1584111720000],
#  ['605501', '611800', '600001', '600001', '11.1518', 1584111780000],
#  ['601233', '601234', '590000', '590000', '24.2759', 1584111840000],
#  ['592006', '596730', '590050', '591008', '13.8508', 1584111900000],
#  ['591008', '600000', '590101', '598745', '11.8009', 1584111960000],
#  ['598849', '600084', '597401', '598501', '6.3636', 1584112020000],
#  ['598501', '605495', '597401', '603643', '6.0709', 1584112080000],
#  ['603642', '608360', '601112', '608360', '5.1780', 1584112140000],
#  ['608360', '611986', '605576', '608622', '13.1638', 1584112200000],
#  ['605590', '608621', '602545', '604003', '3.5895', 1584112260000],
#  ['604003', '605002', '598500', '604400', '7.2327', 1584112320000],
#  ['604002', '604399', '600011', '604398', '7.7179', 1584112380000],
#  ['604399', '605000', '604000', '604301', '3.5495', 1584112440000],
#  ['604300', '604963', '600101', '603568', '3.3070', 1584112500000],
#  ['600765', '603263', '598500', '598503', '7.1702', 1584112560000],
#  ['598501', '602263', '598500', '602263', '7.3700', 1584112620000],
#  ['602264', '602264', '598592', '601002', '3.2590', 1584112680000],
#  ['601002', '603999', '601001', '602818', '2.2440', 1584112740000],
#  ['602284', '609125', '602284', '609124', '7.3531', 1584112800000],
#  ['609124', '609998', '607000', '607001', '3.7079', 1584112860000],
#  ['607001', '607002', '604702', '606986', '3.8886', 1584112920000],
#  ['604702', '604702', '600000', '601915', '4.5522', 1584112980000],
#  ['601916', '602576', '600000', '602257', '2.2647', 1584113040000],
#  ['602257', '602257', '600124', '602220', '0.3658', 1584113100000],
#  ['602220', '603045', '600227', '602205', '3.6602', 1584113160000],
#  ['602205', '602205', '598000', '598000', '7.6378', 1584113220000],
#  ['598000', '598000', '590000', '590000', '6.2960', 1584113280000],
#  ['591740', '594189', '589500', '593340', '13.1592', 1584113340000],
#  ['591489', '591499', '587000', '589503', '4.9021', 1584113400000],
#  ['589500', '589503', '580000', '580000', '28.9586', 1584113460000],
#  ['580000', '580001', '564006', '578083', '32.4455', 1584113520000],
#  ['577999', '578000', '570300', '572589', '14.0311', 1584113580000],
#  ['572589', '580000', '572189', '574415', '8.5895', 1584113640000],
#  ['574416', '580000', '570000', '576911', '8.7874', 1584113700000],
#  ['576912', '580000', '575000', '577056', '5.3215', 1584113760000],
#  ['576026', '580000', '575618', '580000', '3.1132', 1584113820000],
#  ['580000', '584010', '579392', '580602', '6.3612', 1584113880000],
#  ['580603', '583999', '576819', '579996', '9.2261', 1584113940000],
#  ['579996', '580000', '575614', '575618', '5.3627', 1584114000000],
#  ['575622', '575622', '570000', '570000', '3.0091', 1584114060000],
#  ['571238', '574999', '560130', '560130', '8.5731', 1584114120000],
#  ['561001', '569993', '560130', '561002', '13.5664', 1584114180000],
#  ['561003', '571619', '560000', '562029', '15.1344', 1584114240000],
#  ['562028', '562032', '552000', '561592', '19.3462', 1584114300000],
#  ['561591', '563627', '560019', '560386', '1.8753', 1584114360000],
#  ['560386', '563000', '557000', '560000', '13.8318', 1584114420000],
#  ['559999', '566466', '559997', '565006', '7.1054', 1584114480000],
#  ['565006', '570000', '558999', '564022', '10.2507', 1584114540000],
#  ['568140', '568140', '563756', '563756', '5.5496', 1584114600000],
#  ['564882', '568000', '564882', '566000', '5.8310', 1584114660000],
#  ['566608', '567430', '566000', '567002', '10.6128', 1584114720000],
#  ['567990', '570663', '567561', '570000', '6.2643', 1584114780000],
#  ['570000', '581270', '569603', '580998', '21.0295', 1584114840000],
#  ['580998', '595240', '580998', '590002', '30.2458', 1584114900000],
#  ['590004', '590011', '583803', '585772', '13.2273', 1584114960000],
#  ['585537', '586281', '581000', '585000', '6.0952', 1584115020000],
#  ['585001', '586605', '585000', '586588', '4.1347', 1584115080000],
#  ['586588', '590001', '586588', '587095', '11.0435', 1584115140000],
#  ['587460', '587913', '585834', '587095', '10.9367', 1584115200000],
#  ['587999', '591001', '585001', '585637', '12.3579', 1584115260000],
#  ['585637', '585637', '575100', '580009', '19.3816', 1584115320000],
#  ['580009', '580009', '561177', '569535', '21.9132', 1584115380000],
#  ['569534', '571343', '560300', '568989', '24.5582', 1584115440000],
#  ['568989', '574999', '568303', '572792', '4.8529', 1584115500000],
#  ['572790', '572790', '569993', '570951', '1.7225', 1584115560000],
#  ['570951', '570951', '570000', '570944', '3.2334', 1584115620000],
#  ['570940', '574722', '570014', '574546', '3.9135', 1584115680000],
#  ['574397', '576000', '574188', '576000', '3.0919', 1584115740000],
#  ['576000', '576596', '576000', '576001', '3.4264', 1584115800000],
#  ['576496', '581673', '576399', '579800', '3.8162', 1584115860000],
#  ['580939', '580941', '578451', '580540', '6.0274', 1584115920000],
#  ['580539', '580544', '577482', '577500', '10.5331', 1584115980000],
#  ['577500', '577500', '576860', '577500', '8.7565', 1584116040000],
#  ['577500', '581208', '577500', '581208', '5.6289', 1584116100000],
#  ['582365', '585005', '581000', '584400', '19.4146', 1584116160000],
#  ['584401', '585000', '583233', '585000', '8.9909', 1584116220000],
#  ['585000', '589999', '584999', '587190', '9.1311', 1584116280000],
#  ['587189', '589997', '587187', '589996', '4.4315', 1584116340000],
#  ['589996', '590000', '584998', '586804', '7.9309', 1584116400000],
#  ['586802', '588390', '586046', '587926', '4.6707', 1584116460000],
#  ['587922', '587922', '584500', '586134', '2.1981', 1584116520000],
#  ['584506', '585507', '578156', '581852', '5.7042', 1584116580000],
#  ['579932', '585559', '576951', '584213', '9.7306', 1584116640000],
#  ['584213', '584213', '575114', '581994', '5.8594', 1584116700000],
#  ['581991', '582322', '580344', '580560', '2.8303', 1584116760000],
#  ['582322', '584000', '581786', '584000', '5.8665', 1584116820000],
#  ['584008', '586807', '584003', '585520', '1.5694', 1584116880000],
#  ['585830', '587448', '584049', '584049', '2.9735', 1584116940000],
#  ['586978', '588000', '586978', '588000', '1.1467', 1584117000000],
#  ['588010', '589005', '585001', '588089', '8.1813', 1584117060000],
#  ['588694', '590000', '585000', '590000', '10.5865', 1584117120000],
#  ['590000', '598000', '590000', '597999', '10.2762', 1584117180000],
#  ['598000', '599986', '588005', '596010', '9.7368', 1584117240000],
#  ['596010', '598199', '590000', '595300', '2.2028', 1584117300000],
#  ['595300', '597633', '595297', '596366', '1.1474', 1584117360000],
#  ['596360', '597634', '595501', '595501', '0.8810', 1584117420000],
#  ['595511', '596145', '594860', '596000', '2.2887', 1584117480000],
#  ['596000', '596419', '596000', '596419', '1.3951', 1584117540000],
#  ...]
